# %%
# %matplotlib inline

# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

states_df = pd.read_csv('PlottingData2.csv')

states_df.tail()
# Out:
#                   State  Per Capita Personal Income  Average Housing Price  \
# 42             Virginia                 46856.00000            337822.9885
# 43           Washington                 46863.00000            423222.5641
# 44        West Virginia                 37906.00000            184063.6364
# 45            Wisconsin                 45679.00000            200396.4286
# 46  United States Total                 44437.95652            267631.2177
#
#     Count of Targets  Count of Starbucks Count of Walgreens  \
# 42                59                 432                228
# 43                37                 757                136
# 44                 6                  25                116
# 45                37                 145                227
# 46              1815               13424               9088
#
#     Count of Whole Foods  Count of Home Depot
# 42                    13                   49
# 43                     9                   45
# ...

# %%
x_axis = np.arange(len(states_df))
tick_locations = [value+0.4 for value in x_axis]

plt.figure(figsize=(20,3))
plt.bar(x_axis, states_df["Per Capita Personal Income"], color='b', alpha=0.3, align="edge")
plt.xticks(tick_locations, states_df["State"], rotation=70)

plt.xlim(-0.50, len(x_axis))
plt.ylim(0, max(states_df["Per Capita Personal Income"])+10000)

plt.title("Per Capita Personal Income")
plt.xlabel("State")
plt.ylabel("Per Capita Personal Income")

plt.savefig("Per_Capita_Income.png")
plt.show()
