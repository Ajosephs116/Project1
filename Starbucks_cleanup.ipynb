# %%
# Import Dependencies
import pandas as pd

# %%
csv_path = "Data/starbucks_clean.csv"
starbucks_data = pd.read_csv(csv_path)
starbucks_data.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# ...

# %%
us_starbucks_data = starbucks_data.loc[starbucks_data["Country"] == "US", :]
us_starbucks_data
# Out:
#            Brand  Store Number                           Store Name  \
# 11964  Starbucks  22118-217844             344 Russell St (Route 9)
# 11965  Starbucks  27539-243604                       Target Holyoke
# 11966    Teavana  28602-249856               Teavana - Holyoke Mall
# 11967  Starbucks  26040-243285                               Ludlow
# 11968  Starbucks  47243-256546              MA-Turnpike Ludlow West
# 11969  Starbucks  29501-252014         Price Chopper Pittsfield 140
# 11970  Starbucks  29457-253887                        Athol Commons
# 11971  Starbucks  23424-230204                Littleton - The Point
# 11972  Starbucks  47423-256527            MA - Turnpike Ludlow East
# 11973  Starbucks  16899-169785                 Route 20 & Shops Way
# 11974  Starbucks  22110-212351       Price Chopper Shrewsbury # 229
# 11975  Starbucks  19256-195070          Price Chopper Webster # 240
# 11976  Starbucks  28505-250707     Sutton, Pleasant Valley Crossing
# ...

# %%
states_starbucks_data = us_starbucks_data.groupby(["State/Province"])
#print(states_starbucks_data)
states_starbucks_data.count().head()
# Out:
#                 Brand  Store Number  Store Name  Ownership Type  \
# State/Province
# AK                 49            49          49              49
# AL                 85            85          85              85
# AR                 55            55          55              55
# AZ                488           488         488             488
# CA               2821          2821        2821            2821
#
#                 Street Address  City  Country  Postcode  Phone Number  \
# State/Province
# AK                          49    49       49        49            41
# AL                          85    85       85        85            83
# AR                          55    55       55        55            53
# AZ                         488   488      488       488           474
# CA                        2821  2821     2821      2821          2767
#
#                 Timezone  Longitude  Latitude
# State/Province
# AK                    49         49        49
# ...

# %%
states_starbucks_data["Store Name"].count()
# Out:
# State/Province
# AK      49
# AL      85
# AR      55
# AZ     488
# CA    2821
# CO     481
# CT     123
# DC      91
# DE      25
# FL     694
# GA     326
# HI      99
# IA      89
# ID      67
# IL     575
# IN     221
# KS      94
# KY     116
# LA      84
# MA     273
# MD     257
# ME      30
# MI     283
# MN     184
# MO     188
# MS      32
# MT      36
# NC     338
# ND      13
# NE      58
# NH      29
# NJ     261
# NM      76
# NV     253
# NY     645
# OH     378
# OK      79
# OR     359
# PA     357
# RI      27
# SC     131
# SD      25
# TN     180
# TX    1042
# UT     101
# VA     432
# VT       8
# WA     757
# WI     145
# WV      25
# WY      23
# Name: Store Name, dtype: int64
