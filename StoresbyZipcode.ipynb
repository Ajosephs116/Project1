# %%
# %matplotlib inline

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

total_df = pd.read_csv('Data/ProjectOne.csv')

total_df.head()
# Out:
#    Unnamed: 0  zipcode       StateName   2018-12  starbucks_count  \
# 0           0    15237    Pennsylvania  230100.0              6.0
# 1           1    28277  North Carolina  325600.0             10.0
# 2           2    94538      California  919700.0             10.0
# 3           3    93003      California  555200.0             10.0
# 4           4    60657        Illinois  429700.0              9.0
#
#    target_count  fastfoodstores  total
# 0           3.0             1.0     10
# 1           2.0             NaN     12
# 2           2.0             2.0     14
# 3           2.0             1.0     13
# 4           2.0             NaN     11

# %%
sort_total_df = total_df.sort_values(by=['total'], ascending=False)
top_total_df = sort_total_df.head(20)
top_total_df
# Out:
#       Unnamed: 0  zipcode   StateName    2018-12  starbucks_count  \
# 1293        1293    89109      Nevada   290900.0             32.0
# 94            94    45069        Ohio   236600.0              7.0
# 487          487    41042    Kentucky   145900.0              3.0
# 1294        1294    90045  California        NaN             21.0
# 208          208    23185    Virginia   309500.0              5.0
# 203          203    99336  Washington   242800.0              5.0
# 1295        1295    92101  California   510800.0             20.0
# 1296        1296    80202    Colorado   534200.0             17.0
# 243          243    99352  Washington   319500.0              5.0
# 50            50    92626  California   772400.0             13.0
# 115          115    93454  California   346300.0              7.0
# 728          728    45011        Ohio   220100.0              2.0
# 60            60    97223      Oregon   409200.0             10.0
# 1481        1481    47906     Indiana   209700.0              4.0
# 58            58    91355  California   521500.0             11.0
# 1297        1297    98004  Washington  1313800.0             15.0
# 57            57    95678  California   395100.0             11.0
# 654          654    71105   Louisiana   143700.0              3.0
# 55            55    33607     Florida   190100.0             12.0
# 62            62    80501    Colorado        NaN             10.0
#
#       target_count  fastfoodstores  total
# 1293           NaN             5.0     37
# 94             1.0            16.0     24
# 487            1.0            19.0     23
# 1294           NaN             1.0     22
# 208            1.0            15.0     21
# 203            1.0            15.0     21
# 1295           NaN             NaN     20
# 1296           NaN             1.0     18
# 243            1.0            12.0     18
# 50             1.0             3.0     17
# 115            1.0             9.0     17
# 728            1.0            14.0     17
# 60             1.0             5.0     16
# 1481           NaN            12.0     16
# 58             1.0             3.0     15
# 1297           NaN             NaN     15
# 57             1.0             3.0     15
# 654            1.0            11.0     15
# 55             1.0             2.0     15
# 62             1.0             4.0     15

# %%
x_axis = np.arange(len(top_total_df))
tick_locations = [value+0.4 for value in x_axis]

plt.figure(figsize=(20,3))
plt.bar(x_axis, top_total_df["total"], color='b', alpha=0.3, align="edge")
plt.xticks(tick_locations, top_total_df["zipcode"], rotation=70)

plt.xlim(-0.50, len(x_axis))
plt.ylim(0, max(top_total_df["total"])+5)

plt.title("Total Number of Stores by Zipcode")
plt.xlabel("Zipcode")
plt.ylabel("Total Number of Stores")

plt.figtext(0.65,0.8, "Top 3 States: Nevada(89109), Ohio(45069), Kentucky(41042)")

plt.savefig("StoresbyZipcode.png")
plt.show()
